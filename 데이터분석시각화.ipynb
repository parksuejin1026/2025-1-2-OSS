# %% [markdown]
# <a href="https://colab.research.google.com/github/parksuejin1026/2025-2-/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.version
# Out:
# '3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]'

# %% [markdown]
# ###Data 시각화를 위한 한글 설치 및 고화질 설정 (이 기능은 colab에 존재함)

# %%
pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 53.8 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib

# %%
# %config inlinebackend.figure_format = "retina"

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(4,3))
plt.plot([10,20,30]) ###y값 정해주기 x값은 0,1,2로 정해진다
plt.title("첫 그림")
plt.show();

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(4,3))
plt.plot([5,5,10,10,5,5]) ###y값 정해주기 x값은 0,1,2로 정해진다
plt.title("첫 그림")
plt.show();

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(4,3))
plt.plot([5,10,5],[1,2,3]) ###y값 정해주기 x값은 0,1,2로 정해진다
plt.title("첫 그림")
plt.show();

# %%
x = np.linspace(-10, 10, 100) ## -10부터 10까지 100개의 수 뽑기
y = x ** 2

plt.figure(figsize=(3,2))
plt.plot(x,y)
plt.title("y = x^2의 그래프")
plt.show();

# %%
x = np.linspace(-10, 10, 100) ## -10부터 10까지 100개의 수 뽑기
y1 = x ** 2
y2 = x ** 3


plt.figure(figsize=(3,2))
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.title("y = x^2의 그래프")
plt.show();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1950858316.py in <cell line: 0>()
#       9 plt.plot(x,y2)
#      10 plt.plot(x,y3)
# ---> 11 plt.ylimt(-100,100)
#      12 plt.title("y = x^2의 그래프")
#      13 plt.show();
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylimt'
